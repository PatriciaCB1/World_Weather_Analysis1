# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Import the requests library.
import requests
import timeit

# Import the API key.
from config1 import weather_api_key

# Import the datetime module from the datetime library.
from datetime import datetime

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5ab2a73486f9ef38bcff8fef20b04581

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 729

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
#Get the nearest city using the citipy module.
#Retrieve the following information from the API call:

#Latitude and longitude
#Maximum temperature
#Percent humidity
#Percent cloudiness
#Wind speed
#Weather description (for example, clouds, fog, light rain, clear sky)

for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})
        
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | new norfolk
# Processing Record 2 of Set 1 | mahebourg
# Processing Record 3 of Set 1 | saldanha
# Processing Record 4 of Set 1 | hermanus
# Processing Record 5 of Set 1 | sanhsia
# City not found. Skipping...
# Processing Record 6 of Set 1 | avarua
# Processing Record 7 of Set 1 | samarai
# Processing Record 8 of Set 1 | kutum
# Processing Record 9 of Set 1 | castro
# Processing Record 10 of Set 1 | georgetown
# Processing Record 11 of Set 1 | bluff
# Processing Record 12 of Set 1 | vostok
# Processing Record 13 of Set 1 | rikitea
# Processing Record 14 of Set 1 | bengkulu
# Processing Record 15 of Set 1 | yellowknife
# Processing Record 16 of Set 1 | jamestown
# Processing Record 17 of Set 1 | temiscaming
# Processing Record 18 of Set 1 | faanui
# Processing Record 19 of Set 1 | perrenjas
# City not found. Skipping...
# Processing Record 20 of Set 1 | burica
# City not found. Skipping...
# Processing Record 21 of Set 1 | sinnamary
# Processing Record 22 of Set 1 | coquimbo
# Processing Record 23 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 24 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 25 of Set 1 | ushuaia
# Processing Record 26 of Set 1 | busselton
# Processing Record 27 of Set 1 | necochea
# Processing Record 28 of Set 1 | anadyr
# Processing Record 29 of Set 1 | isangel
# Processing Record 30 of Set 1 | thompson
# Processing Record 31 of Set 1 | port elizabeth
# Processing Record 32 of Set 1 | stokmarknes
# Processing Record 33 of Set 1 | waddan
# Processing Record 34 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 35 of Set 1 | berlevag
# Processing Record 36 of Set 1 | zhezkazgan
# Processing Record 37 of Set 1 | mangrol
# Processing Record 38 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 39 of Set 1 | santa cruz
# Processing Record 40 of Set 1 | aasiaat
# Processing Record 41 of Set 1 | puerto ayora
# Processing Record 42 of Set 1 | dikson
# Processing Record 43 of Set 1 | deputatskiy
# Processing Record 44 of Set 1 | fortuna
# Processing Record 45 of Set 1 | axim
# Processing Record 46 of Set 1 | geraldton
# Processing Record 47 of Set 1 | tautira
# Processing Record 48 of Set 1 | katsuura
# Processing Record 49 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 50 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 1 of Set 2 | east london
# Processing Record 2 of Set 2 | saint-philippe
# Processing Record 3 of Set 2 | atuona
# Processing Record 4 of Set 2 | barrow
# Processing Record 5 of Set 2 | khatanga
# Processing Record 6 of Set 2 | meulaboh
# Processing Record 7 of Set 2 | klaksvik
# Processing Record 8 of Set 2 | guerrero negro
# Processing Record 9 of Set 2 | hilo
# Processing Record 10 of Set 2 | qostanay
# Processing Record 11 of Set 2 | kruisfontein
# Processing Record 12 of Set 2 | temaraia
# City not found. Skipping...
# Processing Record 13 of Set 2 | ostrovnoy
# Processing Record 14 of Set 2 | homburg
# Processing Record 15 of Set 2 | mataura
# Processing Record 16 of Set 2 | awjilah
# Processing Record 17 of Set 2 | qaqortoq
# Processing Record 18 of Set 2 | port alfred
# Processing Record 19 of Set 2 | victoria
# Processing Record 20 of Set 2 | allapalli
# Processing Record 21 of Set 2 | ancud
# Processing Record 22 of Set 2 | vardo
# Processing Record 23 of Set 2 | saskylakh
# Processing Record 24 of Set 2 | medeiros neto
# Processing Record 25 of Set 2 | cherskiy
# Processing Record 26 of Set 2 | hobart
# Processing Record 27 of Set 2 | dunedin
# Processing Record 28 of Set 2 | comodoro rivadavia
# Processing Record 29 of Set 2 | wulanhaote
# City not found. Skipping...
# Processing Record 30 of Set 2 | ugoofaaru
# Processing Record 31 of Set 2 | namibe
# Processing Record 32 of Set 2 | hasaki
# Processing Record 33 of Set 2 | luderitz
# Processing Record 34 of Set 2 | saint-pierre
# Processing Record 35 of Set 2 | qingdao
# Processing Record 36 of Set 2 | gamba
# Processing Record 37 of Set 2 | kununurra
# Processing Record 38 of Set 2 | sandwick
# Processing Record 39 of Set 2 | sechura
# Processing Record 40 of Set 2 | severo-kurilsk
# Processing Record 41 of Set 2 | sao jose da coroa grande
# Processing Record 42 of Set 2 | torbay
# Processing Record 43 of Set 2 | pedasi
# Processing Record 44 of Set 2 | madimba
# Processing Record 45 of Set 2 | qaanaaq
# Processing Record 46 of Set 2 | beringovskiy
# Processing Record 47 of Set 2 | windsor
# Processing Record 48 of Set 2 | lebu
# Processing Record 49 of Set 2 | tuatapere
# Processing Record 50 of Set 2 | huaicheng
# Processing Record 1 of Set 3 | kapaa
# Processing Record 2 of Set 3 | ahipara
# Processing Record 3 of Set 3 | zhigansk
# Processing Record 4 of Set 3 | pisco
# Processing Record 5 of Set 3 | khandyga
# Processing Record 6 of Set 3 | bongor
# Processing Record 7 of Set 3 | salym
# Processing Record 8 of Set 3 | namatanai
# Processing Record 9 of Set 3 | airai
# Processing Record 10 of Set 3 | katangli
# Processing Record 11 of Set 3 | labuhan
# Processing Record 12 of Set 3 | toora-khem
# Processing Record 13 of Set 3 | beira
# Processing Record 14 of Set 3 | katsiveli
# City not found. Skipping...
# Processing Record 15 of Set 3 | nadym
# Processing Record 16 of Set 3 | sao filipe
# Processing Record 17 of Set 3 | cape town
# Processing Record 18 of Set 3 | hervey bay
# Processing Record 19 of Set 3 | poum
# Processing Record 20 of Set 3 | kang
# Processing Record 21 of Set 3 | coihaique
# Processing Record 22 of Set 3 | san patricio
# Processing Record 23 of Set 3 | cabo san lucas
# Processing Record 24 of Set 3 | adeje
# Processing Record 25 of Set 3 | gubkinskiy
# Processing Record 26 of Set 3 | mar del plata
# Processing Record 27 of Set 3 | carnarvon
# Processing Record 28 of Set 3 | punta arenas
# Processing Record 29 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 30 of Set 3 | troy
# Processing Record 31 of Set 3 | padang
# Processing Record 32 of Set 3 | pevek
# Processing Record 33 of Set 3 | hithadhoo
# Processing Record 34 of Set 3 | la asuncion
# Processing Record 35 of Set 3 | chilliwack
# Processing Record 36 of Set 3 | tasiilaq
# Processing Record 37 of Set 3 | turtkul
# City not found. Skipping...
# Processing Record 38 of Set 3 | kavieng
# Processing Record 39 of Set 3 | port blair
# Processing Record 40 of Set 3 | taunggyi
# Processing Record 41 of Set 3 | broken hill
# Processing Record 42 of Set 3 | harper
# Processing Record 43 of Set 3 | aswan
# Processing Record 44 of Set 3 | cockburn town
# Processing Record 45 of Set 3 | meyungs
# City not found. Skipping...
# Processing Record 46 of Set 3 | sabla
# Processing Record 47 of Set 3 | vaini
# Processing Record 48 of Set 3 | camacari
# Processing Record 49 of Set 3 | carutapera
# Processing Record 50 of Set 3 | husavik
# Processing Record 1 of Set 4 | kaeo
# Processing Record 2 of Set 4 | upernavik
# Processing Record 3 of Set 4 | bonthe
# Processing Record 4 of Set 4 | bambous virieux
# Processing Record 5 of Set 4 | batagay
# Processing Record 6 of Set 4 | komsomolskiy
# Processing Record 7 of Set 4 | luau
# Processing Record 8 of Set 4 | san cristobal
# Processing Record 9 of Set 4 | rodrigues alves
# Processing Record 10 of Set 4 | santa rosa
# Processing Record 11 of Set 4 | liverpool
# Processing Record 12 of Set 4 | lixourion
# Processing Record 13 of Set 4 | raudeberg
# Processing Record 14 of Set 4 | yulara
# Processing Record 15 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 16 of Set 4 | apastovo
# Processing Record 17 of Set 4 | uri
# Processing Record 18 of Set 4 | bathsheba
# Processing Record 19 of Set 4 | papara
# Processing Record 20 of Set 4 | krivodol
# Processing Record 21 of Set 4 | bako
# Processing Record 22 of Set 4 | payakumbuh
# Processing Record 23 of Set 4 | arraial do cabo
# Processing Record 24 of Set 4 | fairbanks
# Processing Record 25 of Set 4 | hambantota
# Processing Record 26 of Set 4 | guaruja
# Processing Record 27 of Set 4 | haines junction
# Processing Record 28 of Set 4 | challapata
# Processing Record 29 of Set 4 | beloha
# Processing Record 30 of Set 4 | vanino
# Processing Record 31 of Set 4 | butaritari
# Processing Record 32 of Set 4 | quelimane
# Processing Record 33 of Set 4 | isla mujeres
# Processing Record 34 of Set 4 | northam
# Processing Record 35 of Set 4 | sitka
# Processing Record 36 of Set 4 | albany
# Processing Record 37 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 38 of Set 4 | cidreira
# Processing Record 39 of Set 4 | vinukonda
# Processing Record 40 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 41 of Set 4 | severnyy
# Processing Record 42 of Set 4 | ahlat
# Processing Record 43 of Set 4 | oistins
# Processing Record 44 of Set 4 | kyrnasivka
# Processing Record 45 of Set 4 | malibu
# Processing Record 46 of Set 4 | dukat
# Processing Record 47 of Set 4 | mareeba
# Processing Record 48 of Set 4 | hualmay
# Processing Record 49 of Set 4 | dolbeau
# City not found. Skipping...
# Processing Record 50 of Set 4 | howell
# Processing Record 1 of Set 5 | tarauaca
# Processing Record 2 of Set 5 | shingu
# Processing Record 3 of Set 5 | adrar
# Processing Record 4 of Set 5 | wajima
# Processing Record 5 of Set 5 | finnsnes
# Processing Record 6 of Set 5 | fallon
# Processing Record 7 of Set 5 | tuktoyaktuk
# Processing Record 8 of Set 5 | pitangui
# Processing Record 9 of Set 5 | najran
# Processing Record 10 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 11 of Set 5 | vila franca do campo
# Processing Record 12 of Set 5 | kahului
# Processing Record 13 of Set 5 | alofi
# Processing Record 14 of Set 5 | paita
# Processing Record 15 of Set 5 | ambilobe
# Processing Record 16 of Set 5 | goderich
# Processing Record 17 of Set 5 | tromso
# Processing Record 18 of Set 5 | grand baie
# Processing Record 19 of Set 5 | lumsden
# Processing Record 20 of Set 5 | provideniya
# Processing Record 21 of Set 5 | ordynskoye
# Processing Record 22 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 23 of Set 5 | narsaq
# Processing Record 24 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 25 of Set 5 | clyde river
# Processing Record 26 of Set 5 | kijang
# Processing Record 27 of Set 5 | vila do maio
# Processing Record 28 of Set 5 | aklavik
# Processing Record 29 of Set 5 | forssa
# Processing Record 30 of Set 5 | balykshi
# Processing Record 31 of Set 5 | bayir
# Processing Record 32 of Set 5 | santarem
# Processing Record 33 of Set 5 | port-gentil
# Processing Record 34 of Set 5 | edson
# Processing Record 35 of Set 5 | sao joao da barra
# Processing Record 36 of Set 5 | eganville
# Processing Record 37 of Set 5 | nikolskoye
# Processing Record 38 of Set 5 | piltene
# Processing Record 39 of Set 5 | ribeira grande
# Processing Record 40 of Set 5 | cabedelo
# Processing Record 41 of Set 5 | witbank
# Processing Record 42 of Set 5 | lazaro cardenas
# Processing Record 43 of Set 5 | chikoy
# City not found. Skipping...
# Processing Record 44 of Set 5 | catia la mar
# Processing Record 45 of Set 5 | tiksi
# Processing Record 46 of Set 5 | srednekolymsk
# Processing Record 47 of Set 5 | hvolsvollur
# Processing Record 48 of Set 5 | shelburne
# Processing Record 49 of Set 5 | chokurdakh
# Processing Record 50 of Set 5 | ixtapa
# Processing Record 1 of Set 6 | urumqi
# Processing Record 2 of Set 6 | pahrump
# Processing Record 3 of Set 6 | kayerkan
# Processing Record 4 of Set 6 | kvitok
# Processing Record 5 of Set 6 | kodiak
# Processing Record 6 of Set 6 | merauke
# Processing Record 7 of Set 6 | krasnyy mayak
# City not found. Skipping...
# Processing Record 8 of Set 6 | kholmogory
# Processing Record 9 of Set 6 | novoagansk
# Processing Record 10 of Set 6 | baruun-urt
# Processing Record 11 of Set 6 | batagay-alyta
# Processing Record 12 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 13 of Set 6 | jiddah
# City not found. Skipping...
# Processing Record 14 of Set 6 | devyatka
# City not found. Skipping...
# Processing Record 15 of Set 6 | aksu
# Processing Record 16 of Set 6 | ilulissat
# Processing Record 17 of Set 6 | kogon
# Processing Record 18 of Set 6 | asau
# Processing Record 19 of Set 6 | satis
# Processing Record 20 of Set 6 | rongcheng
# Processing Record 21 of Set 6 | nelson bay
# Processing Record 22 of Set 6 | hofn
# Processing Record 23 of Set 6 | hami
# Processing Record 24 of Set 6 | ikongo
# Processing Record 25 of Set 6 | lat yao
# Processing Record 26 of Set 6 | porangatu
# Processing Record 27 of Set 6 | vao
# Processing Record 28 of Set 6 | teguldet
# Processing Record 29 of Set 6 | makakilo city
# Processing Record 30 of Set 6 | saint george
# Processing Record 31 of Set 6 | impfondo
# Processing Record 32 of Set 6 | valverde del camino
# Processing Record 33 of Set 6 | krasnoarmeysk
# Processing Record 34 of Set 6 | bani walid
# Processing Record 35 of Set 6 | la crosse
# Processing Record 36 of Set 6 | kalmunai
# Processing Record 37 of Set 6 | mercedes
# Processing Record 38 of Set 6 | korsakov
# Processing Record 39 of Set 6 | sioux lookout
# Processing Record 40 of Set 6 | leningradskiy
# Processing Record 41 of Set 6 | mankato
# Processing Record 42 of Set 6 | qasigiannguit
# Processing Record 43 of Set 6 | rosario
# Processing Record 44 of Set 6 | uray
# Processing Record 45 of Set 6 | bichura
# Processing Record 46 of Set 6 | maun
# Processing Record 47 of Set 6 | alice springs
# Processing Record 48 of Set 6 | staryy nadym
# Processing Record 49 of Set 6 | ergani
# Processing Record 50 of Set 6 | cap malheureux
# Processing Record 1 of Set 7 | sheregesh
# Processing Record 2 of Set 7 | margate
# Processing Record 3 of Set 7 | mehamn
# Processing Record 4 of Set 7 | hirara
# Processing Record 5 of Set 7 | kindberg
# Processing Record 6 of Set 7 | abay
# Processing Record 7 of Set 7 | yicheng
# Processing Record 8 of Set 7 | ketchikan
# Processing Record 9 of Set 7 | vanavara
# Processing Record 10 of Set 7 | jaciara
# Processing Record 11 of Set 7 | bocaranga
# City not found. Skipping...
# Processing Record 12 of Set 7 | kapoeta
# Processing Record 13 of Set 7 | yerofey pavlovich
# Processing Record 14 of Set 7 | boende
# Processing Record 15 of Set 7 | lompoc
# Processing Record 16 of Set 7 | mana
# Processing Record 17 of Set 7 | taltal
# Processing Record 18 of Set 7 | shwebo
# Processing Record 19 of Set 7 | pacifica
# Processing Record 20 of Set 7 | linares
# Processing Record 21 of Set 7 | japura
# Processing Record 22 of Set 7 | coromandel
# Processing Record 23 of Set 7 | soe
# Processing Record 24 of Set 7 | plastun
# Processing Record 25 of Set 7 | nanortalik
# Processing Record 26 of Set 7 | bantry
# Processing Record 27 of Set 7 | djougou
# Processing Record 28 of Set 7 | pangody
# Processing Record 29 of Set 7 | bredasdorp
# Processing Record 30 of Set 7 | batemans bay
# Processing Record 31 of Set 7 | iqaluit
# Processing Record 32 of Set 7 | agadir
# Processing Record 33 of Set 7 | gizo
# Processing Record 34 of Set 7 | krasnoselkup
# Processing Record 35 of Set 7 | turukhansk
# Processing Record 36 of Set 7 | grindavik
# Processing Record 37 of Set 7 | luwuk
# Processing Record 38 of Set 7 | esperance
# Processing Record 39 of Set 7 | fukue
# Processing Record 40 of Set 7 | tshikapa
# Processing Record 41 of Set 7 | matara
# Processing Record 42 of Set 7 | souillac
# Processing Record 43 of Set 7 | marzuq
# Processing Record 44 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 45 of Set 7 | san policarpo
# Processing Record 46 of Set 7 | shitanjing
# Processing Record 47 of Set 7 | haibowan
# City not found. Skipping...
# Processing Record 48 of Set 7 | codrington
# Processing Record 49 of Set 7 | apatity
# Processing Record 50 of Set 7 | puerto del rosario
# Processing Record 1 of Set 8 | tawnat
# City not found. Skipping...
# Processing Record 2 of Set 8 | trinidad
# Processing Record 3 of Set 8 | inyonga
# Processing Record 4 of Set 8 | zyryanka
# Processing Record 5 of Set 8 | neuquen
# Processing Record 6 of Set 8 | kedgwick
# Processing Record 7 of Set 8 | rorvik
# Processing Record 8 of Set 8 | avera
# Processing Record 9 of Set 8 | port hawkesbury
# Processing Record 10 of Set 8 | bethel
# Processing Record 11 of Set 8 | lere
# Processing Record 12 of Set 8 | billings
# Processing Record 13 of Set 8 | vanimo
# Processing Record 14 of Set 8 | muli
# Processing Record 15 of Set 8 | annau
# Processing Record 16 of Set 8 | beyneu
# Processing Record 17 of Set 8 | lafayette
# Processing Record 18 of Set 8 | mayskiy
# Processing Record 19 of Set 8 | santa maria
# Processing Record 20 of Set 8 | matagami
# Processing Record 21 of Set 8 | longyearbyen
# Processing Record 22 of Set 8 | shimoda
# Processing Record 23 of Set 8 | talnakh
# Processing Record 24 of Set 8 | ilebo
# Processing Record 25 of Set 8 | oranjestad
# Processing Record 26 of Set 8 | zhanatas
# City not found. Skipping...
# Processing Record 27 of Set 8 | quatre cocos
# Processing Record 28 of Set 8 | dauriya
# Processing Record 29 of Set 8 | cairns
# Processing Record 30 of Set 8 | gondanglegi
# Processing Record 31 of Set 8 | berdyuzhye
# City not found. Skipping...
# Processing Record 32 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 33 of Set 8 | chuy
# Processing Record 34 of Set 8 | chiang rai
# Processing Record 35 of Set 8 | yudong
# Processing Record 36 of Set 8 | chapais
# Processing Record 37 of Set 8 | ponta do sol
# Processing Record 38 of Set 8 | tucuma
# Processing Record 39 of Set 8 | kupang
# Processing Record 40 of Set 8 | solovetskiy
# City not found. Skipping...
# Processing Record 41 of Set 8 | clinton
# Processing Record 42 of Set 8 | nizhniy kuranakh
# Processing Record 43 of Set 8 | lisala
# Processing Record 44 of Set 8 | kieta
# Processing Record 45 of Set 8 | ust-maya
# Processing Record 46 of Set 8 | homer
# Processing Record 47 of Set 8 | corinto
# Processing Record 48 of Set 8 | cayenne
# Processing Record 49 of Set 8 | santiago
# Processing Record 50 of Set 8 | port hardy
# Processing Record 1 of Set 9 | macae
# Processing Record 2 of Set 9 | viedma
# Processing Record 3 of Set 9 | fort nelson
# Processing Record 4 of Set 9 | tieli
# Processing Record 5 of Set 9 | bang saphan
# Processing Record 6 of Set 9 | serebryansk
# Processing Record 7 of Set 9 | smithers
# Processing Record 8 of Set 9 | mmabatho
# Processing Record 9 of Set 9 | phan rang
# City not found. Skipping...
# Processing Record 10 of Set 9 | inirida
# Processing Record 11 of Set 9 | kaitangata
# Processing Record 12 of Set 9 | sopelana
# Processing Record 13 of Set 9 | hovd
# Processing Record 14 of Set 9 | port lincoln
# Processing Record 15 of Set 9 | lasa
# Processing Record 16 of Set 9 | karratha
# Processing Record 17 of Set 9 | north bend
# Processing Record 18 of Set 9 | champerico
# Processing Record 19 of Set 9 | san juan
# Processing Record 20 of Set 9 | yarada
# Processing Record 21 of Set 9 | imbituba
# Processing Record 22 of Set 9 | maridi
# Processing Record 23 of Set 9 | talaya
# Processing Record 24 of Set 9 | zonguldak
# Processing Record 25 of Set 9 | portland
# Processing Record 26 of Set 9 | fray bentos
# Processing Record 27 of Set 9 | broome
# Processing Record 28 of Set 9 | weiden
# Processing Record 29 of Set 9 | shakhovskaya
# Processing Record 30 of Set 9 | aurangabad
# Processing Record 31 of Set 9 | hyde
# Processing Record 32 of Set 9 | belyy yar
# Processing Record 33 of Set 9 | buala
# Processing Record 34 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 35 of Set 9 | hanmer springs
# Processing Record 36 of Set 9 | yarmouth
# Processing Record 37 of Set 9 | ijaki
# City not found. Skipping...
# Processing Record 38 of Set 9 | tabas
# Processing Record 39 of Set 9 | praia da vitoria
# Processing Record 40 of Set 9 | trairi
# Processing Record 41 of Set 9 | glendive
# Processing Record 42 of Set 9 | sabang
# Processing Record 43 of Set 9 | tual
# Processing Record 44 of Set 9 | dingle
# Processing Record 45 of Set 9 | agirish
# Processing Record 46 of Set 9 | khuzdar
# Processing Record 47 of Set 9 | brunico
# Processing Record 48 of Set 9 | juneau
# Processing Record 49 of Set 9 | puerto escondido
# Processing Record 50 of Set 9 | flagstaff
# Processing Record 1 of Set 10 | kunnamangalam
# Processing Record 2 of Set 10 | lac-megantic
# Processing Record 3 of Set 10 | los llanos de aridane
# Processing Record 4 of Set 10 | anori
# Processing Record 5 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 6 of Set 10 | jubasan
# Processing Record 7 of Set 10 | isiolo
# Processing Record 8 of Set 10 | tyrma
# Processing Record 9 of Set 10 | umm durman
# City not found. Skipping...
# Processing Record 10 of Set 10 | pangai
# Processing Record 11 of Set 10 | mattru
# Processing Record 12 of Set 10 | halifax
# Processing Record 13 of Set 10 | tumut
# Processing Record 14 of Set 10 | rosetta
# Processing Record 15 of Set 10 | badvel
# Processing Record 16 of Set 10 | caravelas
# Processing Record 17 of Set 10 | grand river south east
# City not found. Skipping...
# Processing Record 18 of Set 10 | inuvik
# Processing Record 19 of Set 10 | planadas
# Processing Record 20 of Set 10 | moerai
# Processing Record 21 of Set 10 | rabat
# Processing Record 22 of Set 10 | norman wells
# Processing Record 23 of Set 10 | buraydah
# Processing Record 24 of Set 10 | roebourne
# Processing Record 25 of Set 10 | keti bandar
# Processing Record 26 of Set 10 | chicama
# Processing Record 27 of Set 10 | killarney
# Processing Record 28 of Set 10 | ulaanbaatar
# Processing Record 29 of Set 10 | felipe carrillo puerto
# Processing Record 30 of Set 10 | palu
# Processing Record 31 of Set 10 | koumac
# Processing Record 32 of Set 10 | bandarbeyla
# Processing Record 33 of Set 10 | puerto madryn
# Processing Record 34 of Set 10 | myitkyina
# Processing Record 35 of Set 10 | formosa
# Processing Record 36 of Set 10 | surt
# Processing Record 37 of Set 10 | misratah
# Processing Record 38 of Set 10 | eldoret
# Processing Record 39 of Set 10 | ballina
# Processing Record 40 of Set 10 | pano polemidia
# Processing Record 41 of Set 10 | gigmoto
# Processing Record 42 of Set 10 | juquitiba
# Processing Record 43 of Set 10 | riverton
# Processing Record 44 of Set 10 | praxedis guerrero
# Processing Record 45 of Set 10 | rawson
# Processing Record 46 of Set 10 | ginda
# Processing Record 47 of Set 10 | santa catarina de tepehuanes
# Processing Record 48 of Set 10 | mackay
# Processing Record 49 of Set 10 | kasongo-lunda
# Processing Record 50 of Set 10 | karlstad
# Processing Record 1 of Set 11 | lavrentiya
# Processing Record 2 of Set 11 | mendoza
# Processing Record 3 of Set 11 | kiunga
# Processing Record 4 of Set 11 | ojinaga
# Processing Record 5 of Set 11 | celestun
# Processing Record 6 of Set 11 | hay river
# Processing Record 7 of Set 11 | salamanca
# Processing Record 8 of Set 11 | vestmannaeyjar
# Processing Record 9 of Set 11 | artyk
# City not found. Skipping...
# Processing Record 10 of Set 11 | yanam
# Processing Record 11 of Set 11 | biak
# Processing Record 12 of Set 11 | shushtar
# Processing Record 13 of Set 11 | neiafu
# Processing Record 14 of Set 11 | torit
# Processing Record 15 of Set 11 | kudahuvadhoo
# Processing Record 16 of Set 11 | inveraray
# City not found. Skipping...
# Processing Record 17 of Set 11 | tessalit
# Processing Record 18 of Set 11 | paragominas
# Processing Record 19 of Set 11 | bokspits
# City not found. Skipping...
# Processing Record 20 of Set 11 | dubenskiy
# City not found. Skipping...
# Processing Record 21 of Set 11 | kimbe
# Processing Record 22 of Set 11 | guilin
# Processing Record 23 of Set 11 | yumen
# Processing Record 24 of Set 11 | cruzeiro do sul
# Processing Record 25 of Set 11 | goba
# Processing Record 26 of Set 11 | agha jari
# City not found. Skipping...
# Processing Record 27 of Set 11 | korla
# Processing Record 28 of Set 11 | guiyang
# Processing Record 29 of Set 11 | mathathane
# Processing Record 30 of Set 11 | duz
# City not found. Skipping...
# Processing Record 31 of Set 11 | urengoy
# Processing Record 32 of Set 11 | pontivy
# Processing Record 33 of Set 11 | sambava
# Processing Record 34 of Set 11 | muros
# Processing Record 35 of Set 11 | acarau
# Processing Record 36 of Set 11 | kidal
# Processing Record 37 of Set 11 | praya
# Processing Record 38 of Set 11 | vila velha
# Processing Record 39 of Set 11 | saulkrasti
# Processing Record 40 of Set 11 | kati
# Processing Record 41 of Set 11 | atar
# Processing Record 42 of Set 11 | longlac
# City not found. Skipping...
# Processing Record 43 of Set 11 | mao
# Processing Record 44 of Set 11 | sisimiut
# Processing Record 45 of Set 11 | nexo
# Processing Record 46 of Set 11 | la tuque
# Processing Record 47 of Set 11 | itarema
# Processing Record 48 of Set 11 | honningsvag
# Processing Record 49 of Set 11 | chifeng
# Processing Record 50 of Set 11 | dondo
# Processing Record 1 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 2 of Set 12 | hamilton
# Processing Record 3 of Set 12 | independence
# Processing Record 4 of Set 12 | acapulco
# Processing Record 5 of Set 12 | arlit
# Processing Record 6 of Set 12 | olafsvik
# Processing Record 7 of Set 12 | nabire
# Processing Record 8 of Set 12 | griffith
# Processing Record 9 of Set 12 | kashan
# Processing Record 10 of Set 12 | pontianak
# Processing Record 11 of Set 12 | alekseyevka
# Processing Record 12 of Set 12 | vysokogornyy
# Processing Record 13 of Set 12 | lashio
# Processing Record 14 of Set 12 | urucara
# Processing Record 15 of Set 12 | bullhead city
# Processing Record 16 of Set 12 | touros
# Processing Record 17 of Set 12 | sidi ali
# Processing Record 18 of Set 12 | gualeguaychu
# Processing Record 19 of Set 12 | bugembe
# Processing Record 20 of Set 12 | falealupo
# City not found. Skipping...
# Processing Record 21 of Set 12 | mbuguni
# Processing Record 22 of Set 12 | stornoway
# Processing Record 23 of Set 12 | acajutla
# Processing Record 24 of Set 12 | quito
# Processing Record 25 of Set 12 | jackson
# Processing Record 26 of Set 12 | vilyuysk
# Processing Record 27 of Set 12 | borbon
# Processing Record 28 of Set 12 | kulhudhuffushi
# Processing Record 29 of Set 12 | xianshuigu
# Processing Record 30 of Set 12 | lorengau
# Processing Record 31 of Set 12 | vesele
# Processing Record 32 of Set 12 | gat
# Processing Record 33 of Set 12 | colares
# Processing Record 34 of Set 12 | aksarka
# Processing Record 35 of Set 12 | maceio
# Processing Record 36 of Set 12 | palauig
# Processing Record 37 of Set 12 | pauini
# Processing Record 38 of Set 12 | bochil
# Processing Record 39 of Set 12 | coahuayana
# Processing Record 40 of Set 12 | kambarka
# Processing Record 41 of Set 12 | boshnyakovo
# Processing Record 42 of Set 12 | amapa
# Processing Record 43 of Set 12 | balikpapan
# Processing Record 44 of Set 12 | hihifo
# City not found. Skipping...
# Processing Record 45 of Set 12 | roald
# Processing Record 46 of Set 12 | kishi
# Processing Record 47 of Set 12 | nguru
# Processing Record 48 of Set 12 | dhangadhi
# Processing Record 49 of Set 12 | pila
# Processing Record 50 of Set 12 | marsabit
# Processing Record 1 of Set 13 | lemesos
# City not found. Skipping...
# Processing Record 2 of Set 13 | daru
# Processing Record 3 of Set 13 | gharo
# Processing Record 4 of Set 13 | port keats
# Processing Record 5 of Set 13 | makasar
# Processing Record 6 of Set 13 | koplik
# Processing Record 7 of Set 13 | abashiri
# Processing Record 8 of Set 13 | mandalgovi
# Processing Record 9 of Set 13 | higuey
# City not found. Skipping...
# Processing Record 10 of Set 13 | salalah
# Processing Record 11 of Set 13 | oyama
# Processing Record 12 of Set 13 | tilichiki
# Processing Record 13 of Set 13 | umm jarr
# City not found. Skipping...
# Processing Record 14 of Set 13 | kant
# Processing Record 15 of Set 13 | chipinge
# Processing Record 16 of Set 13 | fare
# Processing Record 17 of Set 13 | kuandian
# Processing Record 18 of Set 13 | ongwediva
# Processing Record 19 of Set 13 | arteaga
# Processing Record 20 of Set 13 | taua
# Processing Record 21 of Set 13 | bambanglipuro
# Processing Record 22 of Set 13 | murupara
# Processing Record 23 of Set 13 | corn island
# Processing Record 24 of Set 13 | nishihara
# Processing Record 25 of Set 13 | green river
# Processing Record 26 of Set 13 | karanja
# Processing Record 27 of Set 13 | khuzhir
# Processing Record 28 of Set 13 | havoysund
# Processing Record 29 of Set 13 | buariki
# City not found. Skipping...
# Processing Record 30 of Set 13 | sauce
# Processing Record 31 of Set 13 | jumla
# Processing Record 32 of Set 13 | paamiut
# Processing Record 33 of Set 13 | azimur
# City not found. Skipping...
# Processing Record 34 of Set 13 | kracheh
# City not found. Skipping...
# Processing Record 35 of Set 13 | antsohihy
# Processing Record 36 of Set 13 | andenes
# Processing Record 37 of Set 13 | purpe
# Processing Record 38 of Set 13 | tiarei
# Processing Record 39 of Set 13 | chanika
# Processing Record 40 of Set 13 | salaga
# Processing Record 41 of Set 13 | boditi
# Processing Record 42 of Set 13 | yar-sale
# Processing Record 43 of Set 13 | lagoa
# Processing Record 44 of Set 13 | laurel
# Processing Record 45 of Set 13 | kajaani
# Processing Record 46 of Set 13 | honiara
# Processing Record 47 of Set 13 | flinders
# Processing Record 48 of Set 13 | catio
# Processing Record 49 of Set 13 | nome
# Processing Record 50 of Set 13 | mandurah
# Processing Record 1 of Set 14 | pangnirtung
# Processing Record 2 of Set 14 | te karaka
# Processing Record 3 of Set 14 | baraboo
# Processing Record 4 of Set 14 | mahanje
# Processing Record 5 of Set 14 | camana
# Processing Record 6 of Set 14 | portpatrick
# City not found. Skipping...
# Processing Record 7 of Set 14 | les cayes
# Processing Record 8 of Set 14 | durazno
# Processing Record 9 of Set 14 | sohag
# Processing Record 10 of Set 14 | tinyahuarco
# Processing Record 11 of Set 14 | usinsk
# Processing Record 12 of Set 14 | kawalu
# Processing Record 13 of Set 14 | oranjemund
# Processing Record 14 of Set 14 | pyapon
# Processing Record 15 of Set 14 | leh
# Processing Record 16 of Set 14 | manta
# Processing Record 17 of Set 14 | leszno
# Processing Record 18 of Set 14 | mecca
# Processing Record 19 of Set 14 | suoyarvi
# Processing Record 20 of Set 14 | phan thiet
# Processing Record 21 of Set 14 | santo stino di livenza
# Processing Record 22 of Set 14 | marawi
# Processing Record 23 of Set 14 | moraresti
# Processing Record 24 of Set 14 | mount gambier
# Processing Record 25 of Set 14 | denizli
# Processing Record 26 of Set 14 | bowen
# Processing Record 27 of Set 14 | rovaniemi
# Processing Record 28 of Set 14 | bossier city
# Processing Record 29 of Set 14 | gimli
# Processing Record 30 of Set 14 | saint-jean-de-maurienne
# Processing Record 31 of Set 14 | qui nhon
# Processing Record 32 of Set 14 | ustye
# Processing Record 33 of Set 14 | blumenau
# Processing Record 34 of Set 14 | bud
# Processing Record 35 of Set 14 | sitrah
# Processing Record 36 of Set 14 | san alberto
# Processing Record 37 of Set 14 | iskateley
# Processing Record 38 of Set 14 | mayo
# Processing Record 39 of Set 14 | ayia galini
# Processing Record 40 of Set 14 | nuuk
# Processing Record 41 of Set 14 | yaan
# Processing Record 42 of Set 14 | puerto carreno
# Processing Record 43 of Set 14 | umm lajj
# Processing Record 44 of Set 14 | rio gallegos
# Processing Record 45 of Set 14 | sant feliu de guixols
# Processing Record 46 of Set 14 | arcos
# Processing Record 47 of Set 14 | paris
# Processing Record 48 of Set 14 | elko
# Processing Record 49 of Set 14 | jatai
# Processing Record 50 of Set 14 | yugo-kamskiy
# Processing Record 1 of Set 15 | byron bay
# Processing Record 2 of Set 15 | vienna
# Processing Record 3 of Set 15 | deniliquin
# Processing Record 4 of Set 15 | auki
# Processing Record 5 of Set 15 | pokhara
# Processing Record 6 of Set 15 | alto araguaia
# Processing Record 7 of Set 15 | chitral
# Processing Record 8 of Set 15 | ocos
# Processing Record 9 of Set 15 | constitucion
# Processing Record 10 of Set 15 | vizinga
# Processing Record 11 of Set 15 | ornskoldsvik
# Processing Record 12 of Set 15 | deoranian
# Processing Record 13 of Set 15 | strzegom
# Processing Record 14 of Set 15 | caucasia
# Processing Record 15 of Set 15 | lanas
# Processing Record 16 of Set 15 | kodino
# Processing Record 17 of Set 15 | ternate
# Processing Record 18 of Set 15 | martapura
# Processing Record 19 of Set 15 | faya
# Processing Record 20 of Set 15 | tura
# Processing Record 21 of Set 15 | magadan
# Processing Record 22 of Set 15 | santa catalina
# Processing Record 23 of Set 15 | alekseyevsk
# Processing Record 24 of Set 15 | muhos
# Processing Record 25 of Set 15 | alihe
# Processing Record 26 of Set 15 | agadez
# Processing Record 27 of Set 15 | borama
# City not found. Skipping...
# Processing Record 28 of Set 15 | winnemucca
# Processing Record 29 of Set 15 | adelaide
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 671

# %%
#Add the data to a new DataFrame - Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  New Norfolk      AU -42.7826  147.0587      70.0        33          30
# 1    Mahebourg      MU -20.4081   57.7000      77.0        88          40
# 2     Saldanha      ZA -33.0117   17.9442      73.4        64           0
# 3     Hermanus      ZA -34.4187   19.2345      70.0        85          47
# 4       Avarua      CK -21.2078 -159.7750      84.2        74          75
#
#    Wind Speed Current Description
# 0        8.99    scattered clouds
# 1        5.75    scattered clouds
# 2        3.44           clear sky
# 3        8.99    scattered clouds
# 4       20.71       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
